# %%
import numpy as np
import time
import pandas as pd
from datetime import datetime, date

# %%
datos_etnias=pd.read_csv(r'./data/etnias_diciembre.csv', delimiter=',', error_bad_lines=False,encoding='utf8')
aprobados_egresados=pd.read_csv(r'./data/input_aprobados_etnias.csv', delimiter=',', error_bad_lines=False,encoding='utf8')
# Out:
# C:\Users\Ggarcia\AppData\Local\Temp\ipykernel_4740\3438175366.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   datos_etnias=pd.read_csv(r'.\data\etnias_diciembre.csv', delimiter=',', error_bad_lines=False,encoding='utf8')
# C:\Users\Ggarcia\AppData\Local\Temp\ipykernel_4740\3438175366.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   aprobados_egresados=pd.read_csv(r'.\data\input_aprobados_etnias.csv', delimiter=',', error_bad_lines=False,encoding='utf8')

# %%
#datos_etnias['CI'] = datos_etnias['CI'].astype('object')
aprobados_egresados['CI'] = aprobados_egresados['CI'].astype('object')

# %%
data_with_etnics = pd.merge(datos_etnias,aprobados_egresados,on='CI',how='right')
# Out:
# C:\Users\Ggarcia\AppData\Local\Temp\ipykernel_4740\844583220.py:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   data_with_etnics = pd.merge(datos_etnias,aprobados_egresados,on='CI',how='right')

# %%
data_with_etnics.drop_duplicates(subset='CI', keep='first', inplace=True)

# %%
data_with_etnics.reset_index(drop=True, inplace=True)

# %%
clean_data_etnics =data_with_etnics[[
       'CI','Nombres y Apellidos', 'Género_y', 'Fecha de Nacimiento', 'Edad_y',
       'País', 'Ciudad',
       'Etnia', 'Provincia de domicilio',
       'Nivel de instrucción', 'Ocupación',
       'Seleccione la actividad económica en la cuál ud se desenvuelve. ',
       'Teléfono', 'Email', 'Fecha de Inicio',
       'Fecha de Finalización', 'Bienvenida(lecciones)',
       'Bienvenida(practica)',
       'Módulo 1: La importancia de la Educación Financiera ¿cómo influye en tu futuro y felicidad?(lecciones)',
       'Módulo 1: La importancia de la Educación Financiera ¿cómo influye en tu futuro y felicidad?(practica)',
       'Módulo 2: Conozcamos el funcionamiento del Sistema Financiero.(lecciones)',
       'Módulo 2: Conozcamos el funcionamiento del Sistema Financiero.(practica)',
       'Módulo 3: Ahorro y consumo responsable.(lecciones)',
       'Módulo 3: Ahorro y consumo responsable.(practica)',
       'Módulo 4: ¿Cómo hago lo que quiero controlando mi dinero y mis recursos?(lecciones)',
       'Módulo 4: ¿Cómo hago lo que quiero controlando mi dinero y mis recursos?(practica)',
       'Examen de Certificación', 'Porcentaje de Asistencia',
       'Estudiante Activo', 'Promedio de prácticas', 'Aprobados Modulo 1',
       'Aprobados Modulo 2', 'Aprobados Modulo 3', 'Aprobados Modulo 4',
       'Etiqueta Estudiante']]

# %%
clean_data_etnics.columns = [
       'CI','Nombres y Apellidos', 'Género', 'Fecha de Nacimiento', 'Edad',
       'País', 'Ciudad',
       'Etnia', 'Provincia de domicilio',
       'Nivel de instrucción', 'Ocupación',
       'Actividad económica que se desenvuelve. ',
       'Teléfono', 'Email', 'Fecha de Inicio',
       'Fecha de Finalización', 'Bienvenida(lecciones)',
       'Bienvenida(practica)',
       'Módulo 1: La importancia de la Educación Financiera ¿cómo influye en tu futuro y felicidad?(lecciones)',
       'Módulo 1: La importancia de la Educación Financiera ¿cómo influye en tu futuro y felicidad?(practica)',
       'Módulo 2: Conozcamos el funcionamiento del Sistema Financiero.(lecciones)',
       'Módulo 2: Conozcamos el funcionamiento del Sistema Financiero.(practica)',
       'Módulo 3: Ahorro y consumo responsable.(lecciones)',
       'Módulo 3: Ahorro y consumo responsable.(practica)',
       'Módulo 4: ¿Cómo hago lo que quiero controlando mi dinero y mi s recursos?(lecciones)',
       'Módulo 4: ¿Cómo hago lo que quiero controlando mi dinero y mis recursos?(practica)',
       'Examen de Certificación', 'Porcentaje de Asistencia',
       'Estudiante Activo', 'Promedio de prácticas', 'Aprobados Modulo 1',
       'Aprobados Modulo 2', 'Aprobados Modulo 3', 'Aprobados Modulo 4',
       'Etiqueta Estudiante']

# %%
clean_data_etnics.to_csv('./etnias/aprobados_con_etnias.csv',index=False)

# %%
'''def filtrar_Estudiantes_aprobados(dataframe):
    dataframe = dataframe[dataframe['Etiqueta Estudiante'] == 'Aprobado']
    return dataframe

data_etnics_aproved = filtrar_Estudiantes_aprobados(clean_data_etnics)    

data_etnics_aproved.to_csv('./output data/output_aproved_data_with_etnics.csv',index=False)'''
# Out:
# "def filtrar_Estudiantes_aprobados(dataframe):\n    dataframe = dataframe[dataframe['Etiqueta Estudiante'] == 'Aprobado']\n    return dataframe\n\ndata_etnics_aproved = filtrar_Estudiantes_aprobados(clean_data_etnics)    \n\ndata_etnics_aproved.to_csv('./output data/output_aproved_data_with_etnics.csv',index=False)"

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
sns.set_style(style='whitegrid')
sns.set_context(context='notebook')
plt.rcParams['figure.figsize'] = (11, 9.4)

# %% [markdown]
# Descargas los datos de la matriz de datos aprobados cuando ya les tengas unido las etnias

# %%
all_data_etnics = pd.read_csv('./data/etnias_graficar.csv')

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.countplot(y='Etnia', data=all_data_etnics, palette='bright')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Cantidad de estudiantes Aprobados por Etnia', fontsize=15)
plt.xlabel('Cantidad de estudiantes')
plt.ylabel('Etnia')
plt.grid(axis='x', linestyle='dotted', linewidth=0.7)
ax.bar_label(ax.containers[0])
#plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('./etnias/graficos/etnias_aprobados.png', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(11, 5))
sns.countplot(y='Etnia', data=all_data_etnics, palette='bright',hue='Género')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Cantidad de estudiantes Aprobados por Etnia', fontsize=15)
plt.xlabel('Cantidad de estudiantes')
plt.ylabel('Etnia')
plt.grid(axis='x', linestyle='dotted', linewidth=0.7)
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
ax.bar_label(ax.containers[2])
#plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('./etnias/graficos/etnias_aprobados_genero.png', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.countplot(y='Nivel de instrucción', data=all_data_etnics, palette='bright')
plt.title('Cantidad de estudiantes Aprobados por Nivel de Instrucción', fontsize=15)
plt.xlabel('Cantidad de estudiantes')
plt.ylabel('Nivel de instrucción')
plt.grid(axis='x', linestyle='dotted', linewidth=0.7)
ax.bar_label(ax.containers[0])
#plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('./etnias/graficos/nivel_instruccion.png', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(11.5, 5))
sns.countplot(y='Nivel de instrucción', data=all_data_etnics, palette='bright',hue='Género')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Cantidad de estudiantes Aprobados por Nivel de Instrucción', fontsize=15)
plt.xlabel('Cantidad de estudiantes')
plt.ylabel('Nivel de instrucción')
plt.grid(axis='x', linestyle='dotted', linewidth=0.7)
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
ax.bar_label(ax.containers[2])
#plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('./etnias/graficos/nivel_instruccion_genero.png', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.countplot(y='Ocupación', data=all_data_etnics, palette='bright')
plt.title('Cantidad de estudiantes Aprobados por Ocupación', fontsize=15)
plt.xlabel('Cantidad de estudiantes')
plt.ylabel('Ocupación')
plt.grid(axis='x', linestyle='dotted', linewidth=0.7)
ax.bar_label(ax.containers[0])
#plt.xticks(rotation=45)
plt.tight_layout()  
plt.savefig('./etnias/graficos/ocupacion.png', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(11, 5))
sns.countplot(y='Ocupación', data=all_data_etnics, palette='bright',hue='Género')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Cantidad de estudiantes Aprobados por Ocupación', fontsize=15)
plt.xlabel('Cantidad de estudiantes')
plt.ylabel('Ocupación')
plt.grid(axis='x', linestyle='dotted', linewidth=0.7)
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
ax.bar_label(ax.containers[2])
#plt.xticks(rotation=45)
plt.tight_layout()  
plt.savefig('./etnias/graficos/ocupacion_genero.png', dpi=300)
